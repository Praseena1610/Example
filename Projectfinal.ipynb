# %%
from automagica import *

# %%
import pandas as pd

# %%
a = pd.read_excel(r'C:\Users\praseena.s\Desktop\Project.xlsx')

# %%
a
# Out:
#     Project Code                           Project Name Business Unit  \
# 0       4RFPDE01              4RF - Product development           PES
# 1       ACEDIO01         Acces IO - M2 DIO and COM Card           PES
# 2       AIRDIG01  Airport Authority - Digital Sky - PES           PES
# 3       CFNAPL01                        Apcela - Portal           PES
# 4       ARRCOM01             Arris - Commscope Platform           PES
# ..           ...                                    ...           ...
# 99      JWSWAS01                      Wiley- WAS - WPNG           PES
# 100     JWSBDA01       Wiley-BigDataEngineeringOffshore           PES
# 101     JWSDMT01                   WIley-DataManagement           PES
# 102     WRKIOS01                   Workboard_Mobile_App           PES
# 103     WRKSER01                  Workboard_Server_Side           PES
#
#     Contract Type  Start Date    End Date  \
# 0           T & M  2019-05-20  2020-03-31
# ...

# %%
c=pd.read_excel(r"C:\Users\praseena.s\Desktop\Reportfinal.xls")

# %%
c
# Out:
# Empty DataFrame
# Columns: [Contract Type, Account name, Project Name, Project Manager, Delivery Manager, BDM, Jan-2020 - USD, PM Submitted Date, DM Approved Date, Finance Generated Date, BDM Submitted Date]
# Index: []

# %%
result = pd.concat([a,c], ignore_index=True, sort=False, join = 'inner')

# %%
result
# Out:
#                               Project Name Contract Type   Project Manager  \
# 0                4RF - Product development         T & M   ravinagakumar.k
# 1           Acces IO - M2 DIO and COM Card   Fixed Price        ajay.menon
# 2    Airport Authority - Digital Sky - PES   Fixed Price  srinivasmurthy.k
# 3                          Apcela - Portal         T & M     dinesh.bhatta
# 4               Arris - Commscope Platform         T & M     dinesh.bhatta
# ..                                     ...           ...               ...
# 99                       Wiley- WAS - WPNG         T & M    VIJAYA.YOGANNA
# 100       Wiley-BigDataEngineeringOffshore         T & M      kalpana.dutt
# 101                   WIley-DataManagement         T & M      kalpana.dutt
# 102                   Workboard_Mobile_App         T & M   Vadivel.Murugan
# 103                  Workboard_Server_Side         T & M   Vadivel.Murugan
#
#      Delivery Manager
# 0          nazim.khan
# ...

# %%
c=c.append(result)

# %%
c
# Out:
#     Contract Type Account name                           Project Name  \
# 0           T & M          NaN              4RF - Product development
# 1     Fixed Price          NaN         Acces IO - M2 DIO and COM Card
# 2     Fixed Price          NaN  Airport Authority - Digital Sky - PES
# 3           T & M          NaN                        Apcela - Portal
# 4           T & M          NaN             Arris - Commscope Platform
# ..            ...          ...                                    ...
# 99          T & M          NaN                      Wiley- WAS - WPNG
# 100         T & M          NaN       Wiley-BigDataEngineeringOffshore
# 101         T & M          NaN                   WIley-DataManagement
# 102         T & M          NaN                   Workboard_Mobile_App
# 103         T & M          NaN                  Workboard_Server_Side
#
#       Project Manager  Delivery Manager  BDM Jan-2020 - USD PM Submitted Date  \
# ...

# %%
c.to_excel(r'C:/Users/praseena.s/Desktop/Reportfinal.xls')
